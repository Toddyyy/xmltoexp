# %% [markdown]
# # 对齐/节奏曲线进度记录
#
# - `test.ipynb` 已经基于对齐结果计算并绘制了节奏曲线。
# - 使用的曲目：Franz Liszt《Mephisto Waltz No.1, S.514》，路径 `ATEPP-1.2/ATEPP-1.2/Franz_Liszt/Mephisto_Waltz_No._1,_S.514/`。
# - 依赖的对齐文件：同目录下的 `*_match.txt`（排除 `_pre_match`、`_err_match`），以及 `score_fmt3x.txt`。
# - 另有示例对齐：Debussy《Pagodes》（`AlignmentTool/batch_pagodes`）里的 `03237`–`03241` 若干演奏，使用 `score_fmt3x.txt` + `*_match.txt`。

# %% [markdown]
# ## 参考代码（未执行）
#
# ```python
# from pathlib import Path
# import pandas as pd
# import numpy as np
# import re
#
# # Liszt 曲目位置
# piece_dir = Path("ATEPP-1.2/ATEPP-1.2/Franz_Liszt/Mephisto_Waltz_No._1,_S.514")
# fmt3x = piece_dir / "score_fmt3x.txt"
# match_files = [
#     p for p in piece_dir.glob("*_match.txt")
#     if not p.stem.endswith(("_pre_match", "_err_match"))
# ]
# print("match 文件数:", len(match_files))
# print("示例:", [p.name for p in match_files[:5]])
#
# # 如果需要：对 Pagodes 的 match 做同样处理
# pagodes_dir = Path("AlignmentTool/batch_pagodes")
# pagodes_matches = [
#     p for p in pagodes_dir.glob("03*_match.txt")
#     if "pre" not in p.name and "err" not in p.name
# ]
# print("Pagodes match 文件数:", len(pagodes_matches))
# ```
